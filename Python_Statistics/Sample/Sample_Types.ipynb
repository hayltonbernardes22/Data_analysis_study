# %% [markdown]
# # Sample Types
#
# When we talk about statistics, we can come up with a dilemma:
#
# • With more data, and better to get information about my population, however, how would we do to collect data from the entire population of the United States of America, to predict the intention to vote in the 2020 election. I can't, but I can get some sample of this population, trying to obtain the best forecast for this.

# %% [markdown]
# ![american%20election.jpg](attachment:american%20election.jpg)

# %% [markdown]
# So, could I get some reliable sample from my population to get forecasts with formidable accuracy?
#
# It depends....
#
# > In this file I will present some types of samples for you to improve your statistical predictions!

# %%
# Import Library
import pandas as pd
import random
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %% [markdown]
# # Probability Sampling Methods
# ## 1- Random Number Table
#
# This is a old methody, nowadays isn't soo using, however is interesting to talking about.
#
# In this methody, you creat some random table and select yours Data Identification, according to the table, like that:

# %%
random.seed(1)
table = print(np.random.randint(low = 0, high = 9, size = 888))
table
# Out:
# [2 2 8 4 6 0 0 8 6 1 4 1 1 6 0 2 0 6 2 2 0 8 2 1 6 8 3 1 8 1 6 8 0 2 0 5 0
#  0 5 0 7 2 1 4 4 6 5 5 4 5 4 6 4 1 8 7 7 4 5 8 4 8 0 7 5 7 7 3 0 4 0 0 5 1
#  4 4 0 4 3 2 5 4 3 7 5 1 2 5 7 8 8 0 1 5 7 4 7 2 5 0 6 8 1 0 4 5 4 5 3 2 2
#  7 5 7 3 2 8 1 3 7 0 0 1 8 2 0 2 5 8 1 0 1 6 3 4 8 8 2 7 7 2 0 1 5 4 8 4 5
#  3 1 8 3 2 3 5 0 7 4 1 7 0 7 5 8 4 7 6 6 1 4 6 3 5 4 4 5 3 1 5 2 0 2 1 4 0
#  1 7 3 5 8 5 0 1 4 4 0 8 2 1 2 7 1 7 3 0 0 6 5 4 0 3 2 2 0 6 0 2 1 8 4 7 6
#  5 7 5 7 6 4 7 1 2 8 8 5 3 1 1 0 8 3 4 1 8 4 0 1 8 8 5 4 4 2 5 5 7 8 1 4 6
#  0 7 4 3 8 2 8 0 6 2 1 0 8 7 2 4 7 6 1 2 4 3 8 8 2 1 6 7 4 1 7 0 8 0 2 1 5
#  0 0 7 3 2 0 2 7 2 0 6 6 2 0 2 8 2 5 0 7 5 3 3 8 1 1 3 4 0 5 6 8 4 3 8 7 4
#  3 4 4 6 1 5 1 1 0 3 2 3 4 7 6 3 6 2 6 3 0 6 3 4 5 8 7 0 5 1 3 6 5 2 0 7 3
#  5 4 4 6 3 2 3 7 3 8 2 8 5 1 6 7 0 1 4 5 8 6 3 5 1 7 8 4 1 8 5 4 1 2 4 3 0
#  4 4 1 3 2 2 6 4 3 0 8 4 4 2 3 7 3 0 4 3 6 4 8 8 6 5 4 2 0 0 8 6 8 0 2 1 2
# ...

# %% [markdown]
# It depends on the length of the data set, as an example, 2534 rows, this length is 4 characters long, so you should divide this table into IDs of 4 of 4.
#
# • Obtaining IDs: 0712, 2888, 4610, 1307 and so on ....

# %% [markdown]
# Outher example, if your lenght dataset is 90, and my table is that:

# %% [markdown]
# ![Captura%20de%20Tela%202020-10-23%20a%CC%80s%2008.19.10.png](attachment:Captura%20de%20Tela%202020-10-23%20a%CC%80s%2008.19.10.png)

# %% [markdown]
# My sample will be, thats IDs:

# %% [markdown]
# ![Captura%20de%20Tela%202020-10-23%20a%CC%80s%2008.22.08.png](attachment:Captura%20de%20Tela%202020-10-23%20a%CC%80s%2008.22.08.png)

# %% [markdown]
# In this case, just the ID 92 won't be used, because the dataset finish in 90.

# %% [markdown]
# ## 2- Simple Random Sample
#
# In statistics, a simple random sample is a subset of individuals (a sample) chosen from a larger set (a population). Each individual is chosen randomly and entirely by chance, such that each individual has the same probability of being chosen at any stage during the sampling process, and each subset of k individuals has the same probability of being chosen for the sample as any other subset of k individuals. This process and technique is known as simple random sampling, and should not be confused with systematic random sampling. A simple random sample is an unbiased surveying technique.

# %%
# Example Data
list1 = [1, 2, 3, 4, 5, 6] 
print(list1)

# Example Simple Random Sample
print("Some Sample:", random.sample(list1, 3))
# Out:
# [1, 2, 3, 4, 5, 6]
# Some Sample: [2, 5, 1]

# %%
# Building a function to select a simple random sample
def simple_random_sample(dataset,number_sample):
    return dataset.sample(n= number_sample,random_state = 1)

# %% [markdown]
# ## 3- Systematic Sample
#
# Systematic sampling is a statistical method involving the selection of elements from an ordered sampling frame. The most common form of systematic sampling is an equiprobability method. In this approach, progression through the list is treated circularly, with a return to the top once the end of the list is passed. The sampling starts by selecting an element from the list at random and then every kth element in the frame is selected, where k, is the sampling interval (sometimes known as the skip): this is calculated as:

# %% [markdown]
# ![Captura%20de%20Tela%202020-10-25%20a%CC%80s%2021.18.25.png](attachment:Captura%20de%20Tela%202020-10-25%20a%CC%80s%2021.18.25.png)

# %%
# Builting a function to select a systematic sample
def systematic_sample(dataset,number_sample):
    interval = len(dataset) // number_sample
    random.seed(1)
    begin = random.randint(0,interval)
    index = np.arange(begin, len(dataset), step = interval)
    systematic_sample = dataset.iloc[index]
    return systematic_sample

# %%
# For example, testing Systematic Sample Function
df3 = systematic_sample(df,5)
df3
# Out:
#        age   workclass  final-weight education  education-num  \
# 1100    68           ?        140282   7th-8th              4
# 7612    20     Private         95918       9th              5
# 14124   36     Private        182074   HS-grad              9
# 20636   23     Private        151888   HS-grad              9
# 27148   18   State-gov        389147   HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# 1100    Married-civ-spouse                   ?          Husband   White
# 7612    Married-civ-spouse   Machine-op-inspct          Husband   White
# 14124        Never-married        Adm-clerical   Other-relative   White
# 20636             Divorced        Craft-repair    Not-in-family   White
# 27148        Never-married               Sales    Not-in-family   Black
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 1100      Male             0             0              8   United-States
# ...

# %% [markdown]
# ## 4- Cluster Sample
#
# Cluster sampling is a sampling plan used when mutually homogeneous yet internally heterogeneous groupings are evident in a statistical population. It is often used in marketing research. In this sampling plan, the total population is divided into these groups (known as clusters) and a simple random sample of the groups is selected. The elements in each cluster are then sampled. If all elements in each sampled cluster are sampled, then this is referred to as a "one-stage" cluster sampling plan. If a simple random subsample of elements is selected within each of these groups, this is referred to as a "two-stage" cluster sampling plan. A common motivation for cluster sampling is to reduce the total number of interviews and costs given the desired accuracy. For a fixed sample size, the expected random error is smaller when most of the variation in the population is present internally within the groups, and not between the groups.
#
# • Like the Figure:
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.12.50.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.12.50.png)
# When the data set was divided into four clusters and the sample selected two of them.
#
#
# • Another example is, if the data set was twenty-eight houses and was separated into four groups, in my sample I would select only one of them to use.
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.13.42.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.13.42.png)

# %%
# Building the Function
def cluster_sample(dataset,number_sample):
    interval = len(dataset) / number_sample
    cluster = []
    id_cluster = 0
    count = 0
    for _ in dataset.iterrows():
        cluster.append(id_cluster)
        count += 1
        if count > interval:
            count = 0
            id_cluster += 1
    
    dataset['Cluster'] = cluster
    random.seed(1)
    selected_cluster = random.randint(0,number_sample)
    return dataset[dataset['Cluster'] == selected_cluster]

# %%
df4 = cluster_sample(df,6000)
df4
# Out:
#       age   workclass  final-weight      education  education-num  \
# 6600   33     Private        198660      Bachelors             13
# 6601   44     Private        216116        HS-grad              9
# 6602   62     Private        200922        7th-8th              4
# 6603   40     Private        153372   Some-college             10
# 6604   41     Private        406603        HS-grad              9
# 6605   23   Local-gov        248344   Some-college             10
#
#               marital-status          occupation    relationship    race  \
# 6600      Married-civ-spouse               Sales         Husband   White
# 6601   Married-spouse-absent       Other-service   Not-in-family   Black
# 6602                 Widowed   Machine-op-inspct   Not-in-family   White
# 6603      Married-civ-spouse               Sales         Husband   White
# 6604           Never-married       Other-service   Not-in-family   White
# ...

# %% [markdown]
# ## 5- Stratified Sample
#
# In statistics, stratified sampling is a method of sampling from a population which can be partitioned into subpopulations.
#
# In statistical surveys, when subpopulations within an overall population vary, it could be advantageous to sample each subpopulation (stratum) independently. Stratification is the process of dividing members of the population into homogeneous subgroups before sampling. The strata should define a partition of the population. That is, it should be collectively exhaustive and mutually exclusive: every element in the population must be assigned to one and only one stratum. Then simple random sampling or systematic sampling is applied within each stratum. The objective is to improve the precision of the sample by reducing sampling error. It can produce a weighted mean that has less variability than the arithmetic mean of a simple random sample of the population.
#
# In computational statistics, stratified sampling is a method of variance reduction when Monte Carlo methods are used to estimate population statistics from a known population.
#
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.49.30.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.49.30.png)
#
# The math behind methody:
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.46.07.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.46.07.png)
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.46.21.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.46.21.png)

# %%
split = StratifiedShuffleSplit(test_size = 0.00015)
for x,y in split.split(df,df['income']):
    df_x = df.iloc[x]
    df_y = df.iloc[y]

# %%
df_y
# Out:
#        age workclass  final-weight      education  education-num  \
# 29204   27   Private         55390   Some-college             10
# 15236   20   Private        104164        HS-grad              9
# 24692   33   Private        178587   Some-college             10
# 8659    32   Private        385959        HS-grad              9
# 23429   36   Private        215392      Assoc-voc             11
#
#             marital-status          occupation relationship    race      sex  \
# 29204        Never-married     Farming-fishing    Own-child   White     Male
# 15236        Never-married   Handlers-cleaners    Own-child   White     Male
# 24692            Separated      Prof-specialty    Unmarried   White   Female
# 8659         Never-married        Craft-repair    Own-child   White     Male
# 23429   Married-civ-spouse      Prof-specialty         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income  \
# ...

# %% [markdown]
# The figure that differentiates the different probability sampling methods presented here.:
# ![Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.42.11.png](attachment:Captura%20de%20Tela%202020-10-26%20a%CC%80s%2022.42.11.png)

# %% [markdown]
# # References
#
# https://www.udemy.com/course/estatistica-para-ciencia-de-dados-machine-learning/learn/lecture/22187230?start=15#overview
#
# https://en.wikipedia.org/wiki/
